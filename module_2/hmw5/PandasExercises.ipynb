# %% [markdown]
# # Pandas Exercises

# %% [markdown]
# ## Creating DataFrames and Using Sample Data Sets

# %% [markdown]
# Practice Numpy - https://codesolid.com/numpy-practice-questions-to-make-you-an-expert/
# Practice Pandas - https://codesolid.com/pandas-practice-examples/

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %% [markdown]
# **1.** Using NumPy, create a Pandas DataFrame with five rows and three columns:

# %%
array = np.random.randint(1,100,size=(5, 3))
df = pd.DataFrame(array)

print(array)
print(df)
# Out:
# [[17 17 46]
#  [15 49 25]
#  [70 61 14]
#  [31 33 48]
#  [13 67 56]]
#     0   1   2
# 0  17  17  46
# 1  15  49  25
# 2  70  61  14
# 3  31  33  48
# 4  13  67  56

# %% [markdown]
# **2.** For a Pandas DataFrame created from a NumPy array, what is the default behavior for the labels for the columns?  For the rows?

# %% [markdown]
# The default behavior for the labels for the columns and rows starts from 0, and they are numeric labels (0,1,2...).

# %% [markdown]
# **3.** Create a second DataFrame as above with five rows and three columns, setting the row labels to the names of any five major US cities and the column labels to the first three months of the year.

# %%
# %config IPCompleter.greedy=True
df2 = pd.DataFrame(array, columns=["Janurary","February","March"], index =["Los Angeles","New York","Boston","Chicago","Seattle"])
print(df2)
# Out:
#              Janurary  February  March
# Los Angeles        17        17     46
# New York           15        49     25
# Boston             70        61     14
# Chicago            31        33     48
# Seattle            13        67     56

# %% [markdown]
# **4.** You recall that the Seaborn package has some data sets built in, but can't remember how to list and load them. Assuming the functions to do so have "data" in the name, how might you locate them?  You can assume a Jupyter Notebook / IPython environment and explain the process, or write the code to do it in Python.

# %% [markdown]
# I will type "sb.data" see the list of functions and attributes that contain "data" in the namespace. By doing so, I spotted "sb.get_data_home", "sb.get_dataset_names", "sb.load_dataset". Then, I will read each docstrings to see which function can load the built-in dataset, and it seems like sb.load_dataset() will load an example dataset from the online repository (requires internet). For example, I want to load the example dataset named 'iris'

# %%
sb.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Loading data from CSV

# %% [markdown]
# **5**. Zillow home data is available at this https://www.zillow.com/research/data/
#
# URL: https://files.zillowstatic.com/research/public_csvs/zhvi/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv
#
# Open this file as a DataFrame named df_homes in Pandas.

# %%
url = "https://files.zillowstatic.com/research/public_csvs/zhvi/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"

df_homes = pd.read_csv(url)
print(df_homes)
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0      102001         0    United States    country       NaN  121428.348338
# 1      394913         1     New York, NY        msa        NY  216218.985144
# 2      753899         2  Los Angeles, CA        msa        CA  222303.044856
# 3      394463         3      Chicago, IL        msa        IL  152289.701354
# 4      394514         4       Dallas, TX        msa        TX  125341.331449
# ..        ...       ...              ...        ...       ...            ...
# 890    753929       935       Zapata, TX        msa        TX            NaN
# 891    394743       936    Ketchikan, AK        msa        AK            NaN
# 892    753874       937        Craig, CO        msa        CO   98973.406536
# 893    395188       938       Vernon, TX        msa        TX            NaN
# 894    394767       939       Lamesa, TX        msa        TX            NaN
#
#         2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0    121641.979730  121906.914111  122475.146355  123129.113541  ...
# 1    217137.793836  218065.112352  219944.218493  221890.097976  ...
# 2    223130.294238  224232.182526  226424.570068  228822.354722  ...
# 3    152430.677254  152699.168339  153367.107433  154170.557823  ...
# 4    125397.158916  125461.338304  125628.005434  125847.751482  ...
# ..             ...            ...            ...            ...  ...
# 890            NaN            NaN            NaN            NaN  ...
# 891            NaN            NaN            NaN            NaN  ...
# 892   99226.488457   99697.660699  100368.653492  101148.393050  ...
# 893            NaN            NaN            NaN            NaN  ...
# 894            NaN            NaN            NaN            NaN  ...
#
#         2022-12-31     2023-01-31     2023-02-28     2023-03-31  \
# 0    341524.686817  340331.965361  339460.290723  339398.680892
# 1    607957.914467  607138.375566  605781.039331  606096.535158
# 2    883096.482193  874754.169505  863791.280350  853971.725026
# 3    292513.670485  291906.868582  291753.784548  292397.065395
# 4    373653.261774  371121.004193  368863.612270  367332.301710
# ..             ...            ...            ...            ...
# 890  128820.616257  124500.076959  121698.517557  120678.497416
# 891  393779.436232  391467.727268  389754.325134  387641.460892
# 892  265092.079451  266386.963394  267729.652398  268933.717873
# 893   92945.807423   90805.018699   89793.168060   90918.434770
# 894   98555.664945   96911.961613   95480.069061   95333.335974
#
#         2023-04-30     2023-05-31     2023-06-30     2023-07-31  \
# 0    340364.871948  341993.734727  343935.026591  345686.216142
# 1    608105.120897  612136.785991  616308.017005  619911.494379
# 2    851581.705998  855385.245879  863224.274090  874493.271073
# 3    294085.140305  296271.600804  298827.032389  301362.893227
# 4    366782.695296  367067.613765  367882.973641  368856.669150
# ..             ...            ...            ...            ...
# 890  120861.552144  120377.367718  119691.405639  119336.614239
# 891  386519.303527  386847.150776  388239.179204  389755.421023
# 892  271002.669802  273691.861160  277371.349796  280306.434975
# 893   92419.782770   93680.519832   93642.904321   93103.127344
# 894   95113.849939   95043.243764   93482.512748   91595.110854
#
#         2023-08-31     2023-09-30
# 0    347311.245095  348538.961877
# 1    623211.984905  625939.720932
# 2    888127.785264  901894.488002
# 3    303811.358338  305636.274755
# 4    369775.450746  370189.087719
# ..             ...            ...
# 890  119555.327710  119218.474344
# 891  389345.066681  387400.567422
# 892  282581.826984  283845.901872
# 893   92088.769220   91114.278438
# 894   89555.249204   88424.315230
#
# [895 rows x 290 columns]

# %% [markdown]
# **6.** Save the DataFrame, df_homes, to a local CSV file, "zillow_home_data.csv".

# %%
df_homes.to_csv('zillow_home_data.csv')

# %% [markdown]
# **7.** Load zillow_home_data.csv back into a new Dataframe, df_homes_2

# %%
df_homes_2 = pd.read_csv("zillow_home_data.csv")

print(df_homes_2)
# Out:
#      Unnamed: 0  RegionID  SizeRank       RegionName RegionType StateName  \
# 0             0    102001         0    United States    country       NaN
# 1             1    394913         1     New York, NY        msa        NY
# 2             2    753899         2  Los Angeles, CA        msa        CA
# 3             3    394463         3      Chicago, IL        msa        IL
# 4             4    394514         4       Dallas, TX        msa        TX
# ..          ...       ...       ...              ...        ...       ...
# 890         890    753929       935       Zapata, TX        msa        TX
# 891         891    394743       936    Ketchikan, AK        msa        AK
# 892         892    753874       937        Craig, CO        msa        CO
# 893         893    395188       938       Vernon, TX        msa        TX
# 894         894    394767       939       Lamesa, TX        msa        TX
#
#         2000-01-31     2000-02-29     2000-03-31     2000-04-30  ...  \
# 0    121428.348338  121641.979730  121906.914111  122475.146355  ...
# 1    216218.985144  217137.793836  218065.112352  219944.218493  ...
# 2    222303.044856  223130.294238  224232.182526  226424.570068  ...
# 3    152289.701354  152430.677254  152699.168339  153367.107433  ...
# 4    125341.331449  125397.158916  125461.338304  125628.005434  ...
# ..             ...            ...            ...            ...  ...
# 890            NaN            NaN            NaN            NaN  ...
# 891            NaN            NaN            NaN            NaN  ...
# 892   98973.406536   99226.488457   99697.660699  100368.653492  ...
# 893            NaN            NaN            NaN            NaN  ...
# 894            NaN            NaN            NaN            NaN  ...
#
#         2022-12-31     2023-01-31     2023-02-28     2023-03-31  \
# 0    341524.686817  340331.965361  339460.290723  339398.680892
# 1    607957.914467  607138.375566  605781.039331  606096.535158
# 2    883096.482193  874754.169505  863791.280350  853971.725026
# 3    292513.670485  291906.868582  291753.784548  292397.065395
# 4    373653.261774  371121.004193  368863.612270  367332.301710
# ..             ...            ...            ...            ...
# 890  128820.616257  124500.076959  121698.517557  120678.497416
# 891  393779.436232  391467.727268  389754.325134  387641.460892
# 892  265092.079451  266386.963394  267729.652398  268933.717873
# 893   92945.807423   90805.018699   89793.168060   90918.434770
# 894   98555.664945   96911.961613   95480.069061   95333.335974
#
#         2023-04-30     2023-05-31     2023-06-30     2023-07-31  \
# 0    340364.871948  341993.734727  343935.026591  345686.216142
# 1    608105.120897  612136.785991  616308.017005  619911.494379
# 2    851581.705998  855385.245879  863224.274090  874493.271073
# 3    294085.140305  296271.600804  298827.032389  301362.893227
# 4    366782.695296  367067.613765  367882.973641  368856.669150
# ..             ...            ...            ...            ...
# 890  120861.552144  120377.367718  119691.405639  119336.614239
# 891  386519.303527  386847.150776  388239.179204  389755.421023
# 892  271002.669802  273691.861160  277371.349796  280306.434975
# 893   92419.782770   93680.519832   93642.904321   93103.127344
# 894   95113.849939   95043.243764   93482.512748   91595.110854
#
#         2023-08-31     2023-09-30
# 0    347311.245095  348538.961877
# 1    623211.984905  625939.720932
# 2    888127.785264  901894.488002
# 3    303811.358338  305636.274755
# 4    369775.450746  370189.087719
# ..             ...            ...
# 890  119555.327710  119218.474344
# 891  389345.066681  387400.567422
# 892  282581.826984  283845.901872
# 893   92088.769220   91114.278438
# 894   89555.249204   88424.315230
#
# [895 rows x 291 columns]

# %% [markdown]
# **8.** Compare the dimensions of the two DataFrames, df_homes and df_homes_2.  Are they equal?  If not, how can you fix it?

# %%
df_homes.to_csv('zillow_home_data.csv', index=False)

df_homes_2 = pd.read_csv("zillow_home_data.csv")

print(df_homes_2)
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0      102001         0    United States    country       NaN  121428.348338
# 1      394913         1     New York, NY        msa        NY  216218.985144
# 2      753899         2  Los Angeles, CA        msa        CA  222303.044856
# 3      394463         3      Chicago, IL        msa        IL  152289.701354
# 4      394514         4       Dallas, TX        msa        TX  125341.331449
# ..        ...       ...              ...        ...       ...            ...
# 890    753929       935       Zapata, TX        msa        TX            NaN
# 891    394743       936    Ketchikan, AK        msa        AK            NaN
# 892    753874       937        Craig, CO        msa        CO   98973.406536
# 893    395188       938       Vernon, TX        msa        TX            NaN
# 894    394767       939       Lamesa, TX        msa        TX            NaN
#
#         2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0    121641.979730  121906.914111  122475.146355  123129.113541  ...
# 1    217137.793836  218065.112352  219944.218493  221890.097976  ...
# 2    223130.294238  224232.182526  226424.570068  228822.354722  ...
# 3    152430.677254  152699.168339  153367.107433  154170.557823  ...
# 4    125397.158916  125461.338304  125628.005434  125847.751482  ...
# ..             ...            ...            ...            ...  ...
# 890            NaN            NaN            NaN            NaN  ...
# 891            NaN            NaN            NaN            NaN  ...
# 892   99226.488457   99697.660699  100368.653492  101148.393050  ...
# 893            NaN            NaN            NaN            NaN  ...
# 894            NaN            NaN            NaN            NaN  ...
#
#         2022-12-31     2023-01-31     2023-02-28     2023-03-31  \
# 0    341524.686817  340331.965361  339460.290723  339398.680892
# 1    607957.914467  607138.375566  605781.039331  606096.535158
# 2    883096.482193  874754.169505  863791.280350  853971.725026
# 3    292513.670485  291906.868582  291753.784548  292397.065395
# 4    373653.261774  371121.004193  368863.612270  367332.301710
# ..             ...            ...            ...            ...
# 890  128820.616257  124500.076959  121698.517557  120678.497416
# 891  393779.436232  391467.727268  389754.325134  387641.460892
# 892  265092.079451  266386.963394  267729.652398  268933.717873
# 893   92945.807423   90805.018699   89793.168060   90918.434770
# 894   98555.664945   96911.961613   95480.069061   95333.335974
#
#         2023-04-30     2023-05-31     2023-06-30     2023-07-31  \
# 0    340364.871948  341993.734727  343935.026591  345686.216142
# 1    608105.120897  612136.785991  616308.017005  619911.494379
# 2    851581.705998  855385.245879  863224.274090  874493.271073
# 3    294085.140305  296271.600804  298827.032389  301362.893227
# 4    366782.695296  367067.613765  367882.973641  368856.669150
# ..             ...            ...            ...            ...
# 890  120861.552144  120377.367718  119691.405639  119336.614239
# 891  386519.303527  386847.150776  388239.179204  389755.421023
# 892  271002.669802  273691.861160  277371.349796  280306.434975
# 893   92419.782770   93680.519832   93642.904321   93103.127344
# 894   95113.849939   95043.243764   93482.512748   91595.110854
#
#         2023-08-31     2023-09-30
# 0    347311.245095  348538.961877
# 1    623211.984905  625939.720932
# 2    888127.785264  901894.488002
# 3    303811.358338  305636.274755
# 4    369775.450746  370189.087719
# ..             ...            ...
# 890  119555.327710  119218.474344
# 891  389345.066681  387400.567422
# 892  282581.826984  283845.901872
# 893   92088.769220   91114.278438
# 894   89555.249204   88424.315230
#
# [895 rows x 290 columns]

# %% [markdown]
# df_homes_2 has one more columsn compared to df_homes because df_homes_2 includes the index when writing the df into csv. It could be fixed using index = False when writing the df into a local csv.

# %% [markdown]
# **9.** A remote spreadsheet showing how a snapshot of how traffic increased for a hypothetical website is available here: https://github.com/CodeSolid/CodeSolid.github.io/raw/main/booksource/data/AnalyticsSnapshot.xlsx. Load the worksheet page of the spreasheet data labelled "February 2022" as a DataFrame named "feb".  Note: the leftmost column in the spreadsheet is the index column.

# %%
spreadsheet_url = "https://github.com/CodeSolid/CodeSolid.github.io/raw/main/booksource/data/AnalyticsSnapshot.xlsx"
sheet_name = "February 2022"

feb = pd.read_excel(spreadsheet_url,"February 2022")
print(feb)
# Out:
#    Unnamed: 0  This Month  Last Month  Month to Month Increase
# 0       Users        1800         280                 5.428571
# 1   New Users        1700         298                 4.704698
# 2  Page Views        2534         436                 4.811927

# %% [markdown]
# **10.** The "Month to Month Increase" column is a bit hard to understand, so ignore it for now.  Given the values for "This Month" and "Last Month", create a new column, "Percentage Increase".

# %%
feb = feb.rename(columns={'Month to Month Increase': 'Percentage Increase'})
print(feb)
# Out:
#    Unnamed: 0  This Month  Last Month  Percentage Increase
# 0       Users        1800         280             5.428571
# 1   New Users        1700         298             4.704698
# 2  Page Views        2534         436             4.811927

# %% [markdown]
# ## Basic Operations on Data

# %% [markdown]
# **11.** Using Seaborn, get a dataset about penguins into a dataframe named "df_penguins".  Note that because all of the following questions depend on this example, we'll provide the solution here so no one gets stuck:

# %%
df_penguins = sb.load_dataset('penguins')
df_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# **12.** Write the code to show the the number of rows and columns in df_penguins

# %%
n_rows = df_penguins.shape[0]
n_columns = df_penguins.shape[1]
print(f'Number of rows: {n_rows}')
print(f'Number of columns: {n_columns}')
# Out:
# Number of rows: 344
# Number of columns: 7

# %% [markdown]
# **13.** How might you show the first few rows of df_penguins?

# %%
print(df_penguins.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# **14.** How can you return the unique species of penguins from df_penguins?  How many unique species are there?

# %%
unique_species = df_penguins['species'].unique()

print(unique_species)
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']

# %% [markdown]
# **15.** What function can we use to drop the rows that have missing data?

# %%
print(df_penguins.dropna())
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# **16.** By default, will this modify df_penguins or will it return a copy?

# %% [markdown]
# By defualt, this will return a copy.

# %% [markdown]
# **17.** How can we override the default?

# %% [markdown]
# To override the default, we assign the modified df to the original df or another variable.

# %% [markdown]
# **18.** Create a new DataFrame, df_penguins_full, with the missing data deleted.

# %%
df_penguins_full = df_penguins.dropna()
df_penguins_full
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# **19.** What is the average bill length of a penguin, in millimeters, in this (df_full) data set?

# %%
avg_bill_length = df_penguins_full["bill_length_mm"].mean()

print(f'The average bill length of a penguin, in mm, is {avg_bill_length}.')
# Out:
# The average bill length of a penguin, in mm, is 43.99279279279279.

# %% [markdown]
# **20.** Which of the following is most strongly correlated with bill length?  a) Body mass?  b) Flipper length?  c) Bill depth?  Show how you arrived at the answer.

# %% [markdown]
# To determine which variable is most strongly correlated with bill length, we can compare correlation coefficient which quantifies the strength and direction of a linear relationship between two continuous variables.

# %%
a_correlation_coefficient = df_penguins_full["bill_length_mm"].corr(df_penguins_full["body_mass_g"])
b_correlation_coefficient = df_penguins_full["bill_length_mm"].corr(df_penguins_full["flipper_length_mm"])
c_correlation_coefficient = df_penguins_full["bill_length_mm"].corr(df_penguins_full["bill_depth_mm"])

# strength_a = abs(a_correlation_coefficient)
# strength_b = abs(b_correlation_coefficient)
# strength_c = abs(c_correlation_coefficient)

print(f'The correlation coefficient between bill length and body mass is {a_correlation_coefficient}.')
print(f'The correlation coefficient between bill length and flipper length is {b_correlation_coefficient}.')
print(f'The correlation coefficient between bill length and bill depth is {c_correlation_coefficient}.')
print('Flipper length is most strongly correlated tobill length')
# Out:
# The correlation coefficient between bill length and body mass is 0.5894511101769488.
# The correlation coefficient between bill length and flipper length is 0.6530956386670861.
# The correlation coefficient between bill length and bill depth is -0.2286256359130292.
# Flipper length is most strongly correlated tobill length

# %% [markdown]
# **21.** How could you show the median flipper length, grouped by species?

# %%
median_flipper_length = df_penguins_full.groupby('species')['flipper_length_mm'].median()
print(median_flipper_length)
# Out:
# species
# Adelie       190.0
# Chinstrap    196.0
# Gentoo       216.0
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# **22.** Which species has the longest flippers?

# %% [markdown]
# Gentoo has the longest flippers.

# %% [markdown]
# **23.** Which two species have the most similar mean weight?  Show how you arrived at the answer.

# %% [markdown]
# To answer the question, we need to get mean body mass grouped by species. By running the following code, Adelie and Chinstrap are two species have the most similar mean weighth.

# %%
mean_species_weight = df_penguins_full.groupby('species')['body_mass_g'].mean()
print(mean_species_weight)
# Out:
# species
# Adelie       3706.164384
# Chinstrap    3733.088235
# Gentoo       5092.436975
# Name: body_mass_g, dtype: float64

# %% [markdown]
# **24.** How could you sort the rows by bill length?

# %%
df_penguins_full.sort_values(by='bill_length_mm')
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 142     Adelie      Dream            32.1           15.5              188.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 70      Adelie  Torgersen            33.5           19.0              190.0
# 92      Adelie      Dream            34.0           17.1              185.0
# 18      Adelie  Torgersen            34.4           18.4              184.0
# ..         ...        ...             ...            ...                ...
# 335     Gentoo     Biscoe            55.1           16.0              230.0
# 215  Chinstrap      Dream            55.8           19.8              207.0
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 169  Chinstrap      Dream            58.0           17.8              181.0
# 253     Gentoo     Biscoe            59.6           17.0              230.0
#
#      body_mass_g     sex
# 142       3050.0  Female
# 98        2900.0  Female
# 70        3600.0  Female
# 92        3400.0  Female
# 18        3325.0  Female
# ..           ...     ...
# 335       5850.0    Male
# 215       4000.0    Male
# 321       5600.0    Male
# 169       3700.0  Female
# 253       6050.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# **25.** How could you run the same sort in descending order?

# %%
df_penguins_full.sort_values(by='bill_length_mm', ascending=False)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 253     Gentoo     Biscoe            59.6           17.0              230.0
# 169  Chinstrap      Dream            58.0           17.8              181.0
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 215  Chinstrap      Dream            55.8           19.8              207.0
# 335     Gentoo     Biscoe            55.1           16.0              230.0
# ..         ...        ...             ...            ...                ...
# 18      Adelie  Torgersen            34.4           18.4              184.0
# 92      Adelie      Dream            34.0           17.1              185.0
# 70      Adelie  Torgersen            33.5           19.0              190.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 142     Adelie      Dream            32.1           15.5              188.0
#
#      body_mass_g     sex
# 253       6050.0    Male
# 169       3700.0  Female
# 321       5600.0    Male
# 215       4000.0    Male
# 335       5850.0    Male
# ..           ...     ...
# 18        3325.0  Female
# 92        3400.0  Female
# 70        3600.0  Female
# 98        2900.0  Female
# 142       3050.0  Female
#
# [333 rows x 7 columns]

# %% [markdown]
# **26.** How could you sort by species first, then by body mass?

# %%
df_penguins_full.sort_values(by=['species','bill_length_mm'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 142  Adelie      Dream            32.1           15.5              188.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 92   Adelie      Dream            34.0           17.1              185.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# ..      ...        ...             ...            ...                ...
# 327  Gentoo     Biscoe            53.4           15.8              219.0
# 283  Gentoo     Biscoe            54.3           15.7              231.0
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 321  Gentoo     Biscoe            55.9           17.0              228.0
# 253  Gentoo     Biscoe            59.6           17.0              230.0
#
#      body_mass_g     sex
# 142       3050.0  Female
# 98        2900.0  Female
# 70        3600.0  Female
# 92        3400.0  Female
# 18        3325.0  Female
# ..           ...     ...
# 327       5500.0    Male
# 283       5650.0    Male
# 335       5850.0    Male
# 321       5600.0    Male
# 253       6050.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## Selecting Rows, Columns, and Cells
#
# Let's look at some precious stones now, and leave the poor penguins alone for a while.  Let's look at some precious stones now, and leave the poor penguins alone for a while.

# %% [markdown]
# **27.** Load the Seaborn "diamonds" dataset into a Pandas dataframe named diamonds.

# %%
df_diamonds = sb.load_dataset('diamonds')
df_diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# **28.** Display the columns that are available.

# %%
for col in df_diamonds.columns:
    print(col)
# Out:
# carat
# cut
# color
# clarity
# depth
# table
# price
# x
# y
# z

# %% [markdown]
# **29.** If you select a single column from the diamonds DataFrame, what will be the type of the return value?

# %% [markdown]
# **30.** Select the 'table' column and show its type

# %%
df_diamonds['table'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **31.** Select the first ten rows of the price and carat columns ten rows of the diamonds DataFrame into a variable called subset, and display them.

# %%
subset = df_diamonds[['price', 'carat']][:10]
subset
# Out:
#    price  carat
# 0    326   0.23
# 1    326   0.21
# 2    327   0.23
# 3    334   0.29
# 4    335   0.31
# 5    336   0.24
# 6    336   0.24
# 7    337   0.26
# 8    337   0.22
# 9    338   0.23

# %% [markdown]
# **32.** For a given column, show the code to display the datatype of the _values_ in the column?

# %%
column_name = 'price'
datatype_of_values = subset[column_name].dtype

print(f"The datatype of the values in the '{column_name}' column is: {datatype_of_values}")
# Out:
# The datatype of the values in the 'price' column is: int64

# %% [markdown]
# **33.** Select the first row of the diamonds DataFrame into a variable called row.

# %%
row = df_diamonds.iloc[0]
row
# Out:
# carat       0.23
# cut        Ideal
# color          E
# clarity      SI2
# depth       61.5
# table       55.0
# price        326
# x           3.95
# y           3.98
# z           2.43
# Name: 0, dtype: object

# %% [markdown]
# **34.** What would you expect the data type of the row to be?  Display it.

# %% [markdown]
# A Pandas series

# %%
print(type(row))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# **35.** Can you discover the names of the columns using only the row returned in #33?  Why or why not?Can you discover the names of the columns using only the row returned in #33?  Why or why not?

# %% [markdown]
# Yes, because a row series should have the columns as the index (See below):

# %%
row = df_diamonds.iloc[32]
print(row)
# Out:
# carat           0.23
# cut        Very Good
# color              E
# clarity          VS1
# depth           60.7
# table           59.0
# price            402
# x               3.97
# y               4.01
# z               2.42
# Name: 32, dtype: object

# %% [markdown]
# **36.** Select the row with the highest priced diamond.

# %%
index_max_price = df_diamonds['price'].idxmax()

# Select the row with the highest price
highest_priced_diamond = df_diamonds.iloc[index_max_price]

print(highest_priced_diamond)
# Out:
# carat         2.29
# cut        Premium
# color            I
# clarity        VS2
# depth         60.8
# table         60.0
# price        18823
# x              8.5
# y             8.47
# z             5.16
# Name: 27749, dtype: object

# %% [markdown]
# **37.** Select the row with the lowest priced diamond.

# %%
index_min_price = df_diamonds['price'].idxmin()

# Select the row with the highest price
lowest_priced_diamond = df_diamonds.iloc[index_min_price]

print(lowest_priced_diamond)
# Out:
# carat       0.23
# cut        Ideal
# color          E
# clarity      SI2
# depth       61.5
# table       55.0
# price        326
# x           3.95
# y           3.98
# z           2.43
# Name: 0, dtype: object

# %% [markdown]
# ## Some Exercises Using Time Series

# %% [markdown]
# **38.** Load the taxis dataset into a DataFrame, ```taxis```.

# %%
df_taxis = sb.load_dataset('taxis')
df_taxis
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %% [markdown]
# **39.** The 'pickup' column contains the date and time the customer picked up, but it's a string.  Add a column to the DataFrame, 'pickup_time', containing the value in 'pickup' as a DateTime.

# %%
df_taxis['pickup_time'] = pd.to_datetime(df_taxis['pickup'])

df_taxis
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough  \
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
#              pickup_time
# 0    2019-03-23 20:21:09
# 1    2019-03-04 16:11:55
# 2    2019-03-27 17:53:01
# 3    2019-03-10 01:23:59
# 4    2019-03-30 13:27:42
# ...                  ...
# 6428 2019-03-31 09:51:53
# 6429 2019-03-31 17:38:00
# 6430 2019-03-23 22:55:18
# 6431 2019-03-04 10:09:25
# 6432 2019-03-13 19:31:22
#
# [6433 rows x 15 columns]

# %% [markdown]
# **40.** We have a hypothesis that as the day goes on, the tips get higher.  We'll need to wrangle the data a bit before testing this, however.  First, now that we have a datetime column, pickup_time, create a subset of it to create a new DataFrame, taxis_one_day. This new DataFrame should have values between '2019-03-23 00:06:00' (inclusive) and '2019-03-24 00:00:00' (exlusive).

# %%
taxis_one_day = df_taxis.loc[(df_taxis['pickup_time'] >= '2019-03-23 00:06:00') & (df_taxis['pickup_time'] < '2019-03-24 00:00:00')]
taxis_one_day
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 8    2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0
# 17   2019-03-23 20:50:49 2019-03-23 21:02:07           1      2.60  10.5
# 117  2019-03-23 09:39:25 2019-03-23 09:56:45           0      3.60  15.5
# 144  2019-03-23 18:35:01 2019-03-23 18:47:39           1      3.20  12.5
# ...                  ...                 ...         ...       ...   ...
# 6325 2019-03-23 20:52:40 2019-03-23 21:10:12           1      3.62  14.5
# 6331 2019-03-23 11:27:00 2019-03-23 12:20:11           1      7.67  28.0
# 6338 2019-03-23 18:05:38 2019-03-23 18:25:36           1      2.82  14.0
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
#
#        tip  tolls  total   color      payment                     pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card                 Lenox Hill West
# 8     1.00    0.0  19.30  yellow  credit card               East Harlem South
# 17    2.00    0.0  16.30  yellow  credit card                  Midtown Center
# 117   3.75    0.0  22.55  yellow  credit card                  Yorkville East
# 144   2.00    0.0  17.80  yellow  credit card             UN/Turtle Bay South
# ...    ...    ...    ...     ...          ...                             ...
# 6325  0.00    0.0  15.80   green         cash  Long Island City/Hunters Point
# 6331  0.00    0.0  28.00   green         cash                 Jackson Heights
# 6338  0.00    0.0  14.80   green  credit card              Claremont/Bathgate
# 6427  0.00    0.0  20.00   green         cash                     Parkchester
# 6430  0.00    0.0  17.30   green         cash             Crown Heights North
#
#                       dropoff_zone pickup_borough dropoff_borough  \
# 0              UN/Turtle Bay South      Manhattan       Manhattan
# 8                   Midtown Center      Manhattan       Manhattan
# 17               East Harlem South      Manhattan       Manhattan
# 117   Penn Station/Madison Sq West      Manhattan       Manhattan
# 144                   East Village      Manhattan       Manhattan
# ...                            ...            ...             ...
# 6325                      Steinway         Queens          Queens
# 6331                       Maspeth         Queens          Queens
# 6338    Spuyten Duyvil/Kingsbridge          Bronx           Bronx
# 6427             East Harlem South          Bronx       Manhattan
# 6430                Bushwick North       Brooklyn        Brooklyn
#
#              pickup_time
# 0    2019-03-23 20:21:09
# 8    2019-03-23 11:48:50
# 17   2019-03-23 20:50:49
# 117  2019-03-23 09:39:25
# 144  2019-03-23 18:35:01
# ...                  ...
# 6325 2019-03-23 20:52:40
# 6331 2019-03-23 11:27:00
# 6338 2019-03-23 18:05:38
# 6427 2019-03-23 18:26:09
# 6430 2019-03-23 22:55:18
#
# [209 rows x 15 columns]

# %% [markdown]
# **41.** We now have a range from morning until midnight, but we to take the mean of the numeric columns, grouped at one hour intervals.  Save the result as df_means, and display it.

# %%
numeric_columns = taxis_one_day.select_dtypes(include='number')

taxis_means = numeric_columns.groupby(taxis_one_day['pickup_time'].dt.hour).mean()

# Display the DataFrame with means
taxis_means
# Out:
#              passengers  distance       fare       tip     tolls      total
# pickup_time
# 0              1.000000  1.911667   8.583333  1.415000  0.000000  12.965000
# 1              1.250000  1.325000   7.875000  1.525000  0.000000  12.575000
# 2              1.727273  1.739091   8.181818  1.641818  0.000000  13.169091
# 3              1.500000  3.377500  11.750000  2.410000  0.000000  17.335000
# 4              2.000000  0.950000   5.500000  0.915000  0.000000  10.215000
# 5              2.000000  1.270000   6.000000  0.980000  0.000000  10.530000
# 6              1.000000  0.400000  21.500000  0.000000  0.000000  23.133333
# 7              2.333333  0.980000   5.250000  1.165000  0.000000   9.298333
# 8              1.000000  0.020000   2.500000  0.000000  0.000000   3.300000
# 9              1.500000  1.352000   7.400000  1.674000  0.000000  12.124000
# 10             1.000000  1.760000   8.750000  0.727500  0.000000  12.152500
# 11             1.909091  2.070000  11.090909  0.803636  0.000000  14.667273
# 12             2.000000  2.267143  10.260000  0.645714  0.000000  13.420000
# 13             2.500000  1.167000   7.550000  2.074000  0.000000  12.344000
# 14             2.470588  4.752941  18.330000  1.945294  1.003529  24.267059
# 15             1.000000  6.557143  22.214286  3.210000  1.645714  30.370000
# 16             2.000000  2.194545  10.454545  1.109091  0.000000  14.431818
# 17             1.090909  1.913636  14.818182  2.688182  0.523636  20.739091
# 18             1.571429  3.206429  12.821429  0.844286  0.411429  16.427143
# 19             1.526316  2.097895  10.263158  1.176316  0.000000  14.226316
# 20             1.400000  2.448000  11.100000  1.544000  0.000000  15.944000
# 21             1.000000  2.017143  10.571429  1.420000  0.000000  15.791429
# 22             1.307692  1.881538   8.923077  1.094615  0.000000  13.433077
# 23             1.615385  3.725385  15.115385  1.696154  0.000000  20.034615

# %% [markdown]
# **42.** Create a simple line plot of the value "distance".

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with a 'distance' column
# If not, replace df with your actual DataFrame name

# Create a line plot for the 'distance' column
plt.plot(taxis_means['distance'])

# Add labels and title
plt.xlabel('Hours')
plt.ylabel('Distance')
plt.title('Distance Plot')

# Show the plot
plt.show()

# %% [markdown]
# **43.** Overall, do riders travel further or less far as the day progresses?

# %% [markdown]
# Overall, riders travel further as the day progresses. However, the patter is more like waves.

# %% [markdown]
# **44.** Create a new column in taxis_means, ```tip_in_percent```.  The source columns for this should be "fare" and "tip"

# %%
taxis_means["tip_in_percet"] = (taxis_means["tip"] / taxis_means["fare"]) * 100

taxis_means
# Out:
#              passengers  distance       fare       tip     tolls      total  \
# pickup_time
# 0              1.000000  1.911667   8.583333  1.415000  0.000000  12.965000
# 1              1.250000  1.325000   7.875000  1.525000  0.000000  12.575000
# 2              1.727273  1.739091   8.181818  1.641818  0.000000  13.169091
# 3              1.500000  3.377500  11.750000  2.410000  0.000000  17.335000
# 4              2.000000  0.950000   5.500000  0.915000  0.000000  10.215000
# 5              2.000000  1.270000   6.000000  0.980000  0.000000  10.530000
# 6              1.000000  0.400000  21.500000  0.000000  0.000000  23.133333
# 7              2.333333  0.980000   5.250000  1.165000  0.000000   9.298333
# 8              1.000000  0.020000   2.500000  0.000000  0.000000   3.300000
# 9              1.500000  1.352000   7.400000  1.674000  0.000000  12.124000
# 10             1.000000  1.760000   8.750000  0.727500  0.000000  12.152500
# 11             1.909091  2.070000  11.090909  0.803636  0.000000  14.667273
# 12             2.000000  2.267143  10.260000  0.645714  0.000000  13.420000
# 13             2.500000  1.167000   7.550000  2.074000  0.000000  12.344000
# 14             2.470588  4.752941  18.330000  1.945294  1.003529  24.267059
# 15             1.000000  6.557143  22.214286  3.210000  1.645714  30.370000
# 16             2.000000  2.194545  10.454545  1.109091  0.000000  14.431818
# 17             1.090909  1.913636  14.818182  2.688182  0.523636  20.739091
# 18             1.571429  3.206429  12.821429  0.844286  0.411429  16.427143
# 19             1.526316  2.097895  10.263158  1.176316  0.000000  14.226316
# 20             1.400000  2.448000  11.100000  1.544000  0.000000  15.944000
# 21             1.000000  2.017143  10.571429  1.420000  0.000000  15.791429
# 22             1.307692  1.881538   8.923077  1.094615  0.000000  13.433077
# 23             1.615385  3.725385  15.115385  1.696154  0.000000  20.034615
#
#              tip_in_percet
# pickup_time
# 0                16.485437
# 1                19.365079
# 2                20.066667
# 3                20.510638
# 4                16.636364
# 5                16.333333
# 6                 0.000000
# 7                22.190476
# 8                 0.000000
# 9                22.621622
# 10                8.314286
# 11                7.245902
# 12                6.293512
# 13               27.470199
# 14               10.612625
# 15               14.450161
# 16               10.608696
# 17               18.141104
# 18                6.584958
# 19               11.461538
# 20               13.909910
# 21               13.432432
# 22               12.267241
# 23               11.221374

# %% [markdown]
# **45.** Create a new column, time_interval, as a range of integer values beginning with zero.

# %%
taxis_means['time_interval'] = range(len(taxis_means))

taxis_means
# Out:
#              passengers  distance       fare       tip     tolls      total  \
# pickup_time
# 0              1.000000  1.911667   8.583333  1.415000  0.000000  12.965000
# 1              1.250000  1.325000   7.875000  1.525000  0.000000  12.575000
# 2              1.727273  1.739091   8.181818  1.641818  0.000000  13.169091
# 3              1.500000  3.377500  11.750000  2.410000  0.000000  17.335000
# 4              2.000000  0.950000   5.500000  0.915000  0.000000  10.215000
# 5              2.000000  1.270000   6.000000  0.980000  0.000000  10.530000
# 6              1.000000  0.400000  21.500000  0.000000  0.000000  23.133333
# 7              2.333333  0.980000   5.250000  1.165000  0.000000   9.298333
# 8              1.000000  0.020000   2.500000  0.000000  0.000000   3.300000
# 9              1.500000  1.352000   7.400000  1.674000  0.000000  12.124000
# 10             1.000000  1.760000   8.750000  0.727500  0.000000  12.152500
# 11             1.909091  2.070000  11.090909  0.803636  0.000000  14.667273
# 12             2.000000  2.267143  10.260000  0.645714  0.000000  13.420000
# 13             2.500000  1.167000   7.550000  2.074000  0.000000  12.344000
# 14             2.470588  4.752941  18.330000  1.945294  1.003529  24.267059
# 15             1.000000  6.557143  22.214286  3.210000  1.645714  30.370000
# 16             2.000000  2.194545  10.454545  1.109091  0.000000  14.431818
# 17             1.090909  1.913636  14.818182  2.688182  0.523636  20.739091
# 18             1.571429  3.206429  12.821429  0.844286  0.411429  16.427143
# 19             1.526316  2.097895  10.263158  1.176316  0.000000  14.226316
# 20             1.400000  2.448000  11.100000  1.544000  0.000000  15.944000
# 21             1.000000  2.017143  10.571429  1.420000  0.000000  15.791429
# 22             1.307692  1.881538   8.923077  1.094615  0.000000  13.433077
# 23             1.615385  3.725385  15.115385  1.696154  0.000000  20.034615
#
#              tip_in_percet  time_interval
# pickup_time
# 0                16.485437              0
# 1                19.365079              1
# 2                20.066667              2
# 3                20.510638              3
# 4                16.636364              4
# 5                16.333333              5
# 6                 0.000000              6
# 7                22.190476              7
# 8                 0.000000              8
# 9                22.621622              9
# 10                8.314286             10
# 11                7.245902             11
# 12                6.293512             12
# 13               27.470199             13
# 14               10.612625             14
# 15               14.450161             15
# 16               10.608696             16
# 17               18.141104             17
# 18                6.584958             18
# 19               11.461538             19
# 20               13.909910             20
# 21               13.432432             21
# 22               12.267241             22
# 23               11.221374             23

# %% [markdown]
# Display the correlations between the following pairs of values:
# 1. tip_in_percent and distance.
# 1. tip_in_percent and passengers.
# 1. tip_in_percent and time_interval.

# %%
correlation_tip_distance = taxis_means["tip_in_percet"].corr(taxis_means["distance"])
correlation_tip_passengers = taxis_means["tip_in_percet"].corr(taxis_means["passengers"])
correlation_tip_time_interval = taxis_means["tip_in_percet"].corr(taxis_means["time_interval"])

print(f"Correlation between tip_in_percent and distance: {correlation_tip_distance}")
print(f"Correlation between tip_in_percent and passengers: {correlation_tip_passengers}")
print(f"Correlation between tip_in_percent and time_interval: {correlation_tip_time_interval}")
# Out:
# Correlation between tip_in_percent and distance: 0.00953302789086909
# Correlation between tip_in_percent and passengers: 0.32623184018268747
# Correlation between tip_in_percent and time_interval: -0.23239795213315184

# %% [markdown]
# **47.** Admittedly, the size of the data set is fairly small given how we've subsetted it.  But based on the values in #45, which of the three pairs show the strongest correlation.

# %% [markdown]
# Based on the three pairs, tip_in_percent and passengers show the strongest correlation.

# %% [markdown]
# **48.** Did our hypothesis that people tip more as the day goes on turn out to be warranted?

# %% [markdown]
# Based on the information we have, I would likely to conclude that the hypothesis turn out to be unwarranted since -0.23 suggests fairly weak correlation. However, to have a more valid conclusion, we need larger sample set and more comprehensive hypothesis testing.
